# %%
# Avocado analysis
# Metodos cuantitativos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors

# %%
avocado_data = pd.read_csv("data/avocado.csv")
avocado_data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
# Total Bags
# to slice and get all values of specific column, modify index number of column
n_bins = total_bags.count()
total_bags = avocado_data.iloc[:, 7]
print(total_bags)
plt.hist(total_bags)
plt.show() 
# axs[0].hist(x, bins=n_bins)
# Out:
# 0         8696.87
# 1         9505.56
# 2         8145.35
# 3         5811.16
# 4         6183.95
#            ...
# 18244    13498.67
# 18245     9264.84
# 18246     9394.11
# 18247    10969.54
# 18248    12014.15
# Name: Total Bags, Length: 18249, dtype: float64
# (array([1.522e+03, 1.171e+03, 8.320e+02, ..., 0.000e+00, 0.000e+00,
#         1.000e+00]),
#  array([0.00000000e+00, 1.06159978e+03, 2.12319956e+03, ...,
#         1.93710112e+07, 1.93720728e+07, 1.93731344e+07]),
#  <BarContainer object of 18249 artists>)
